# %%
print('Data Import')

#data mining - data extract, basic information
# Out:
# Data Import

# %%
import seaborn as sns

# %%
sns.__version__  #__version__

# %%
sns.get_dataset_names()

# %%
a = sns.load_dataset('penguins')
a.head()

# %%
a.tail()

# %%
a.shape()

# %%
a.info()
