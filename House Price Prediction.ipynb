# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn import linear_model

house_price = [245, 365, 278, 189, 217, 347, 278, 478, 412, 399]
size = [1800, 2100, 1975, 1450, 1750, 2050, 1850, 2450, 2400, 2350]

size2 = np.array(size).reshape((-1, 1))

regr = linear_model.LinearRegression()
regr.fit(size2, house_price)

print("Coefficients: ", regr.coef_)
print("Intercept : ", regr.intercept_)
# Out:
# Coefficients:  [0.28335208]
# Intercept :  -250.86281417248136

# %%
def graph(formula, x_range):
    x = np.array(x_range)
    y = eval(formula)
    plt.plot(x,y)

# %%
graph('regr.coef_*x + regr.intercept_', range(1500, 5500))
plt.scatter (size, house_price, color='black')
plt.ylabel('Price')
plt.xlabel('Size')
plt.show()

# %%
# data mining
# data cleaning (statical insights)
# visualization
